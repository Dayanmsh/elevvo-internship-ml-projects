# %% [markdown]
# # Task 2: Customer Segmentation
#
# This notebook demonstrates customer segmentation using clustering algorithms on the Mall Customers dataset. It includes EDA, K-Means (with optimal k selection), DBSCAN (bonus), and analysis of average spending per cluster.
